# %%
#Claude Haiku 4.5 was used on this assignment.
#Max Keller 2/24/26
#Will not run as is due to the file path being wrong
import pathlib
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# path to the file (moved location)
GAZETTEER_FILE = pathlib.Path(r"C:\Users\maxke\atmos_py\Project Folders\Data\2025_Gaz_zcta_national.txt")


OUTPUT_SHP = "zip_code_centroids.shp"


def main():
    
    df = pd.read_csv(GAZETTEER_FILE, delimiter="|", dtype=str)

    # store the ZIP cod code as a string
    df["ZIP"] = df["GEOID"].astype(str)


    df["INTPTLAT"] = pd.to_numeric(df["INTPTLAT"], errors="coerce")
    df["INTPTLONG"] = pd.to_numeric(df["INTPTLONG"], errors="coerce")


    df = df.dropna(subset=["INTPTLAT", "INTPTLONG"])


    geometry = [Point(xy) for xy in zip(df["INTPTLONG"], df["INTPTLAT"])]

    # create a GeoDataFrame
    gdf = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")


    gdf = gdf[["ZIP", "geometry"]]

    
    print(f"Writing {len(gdf)} centroids to {OUTPUT_SHP}...")
    gdf.to_file(OUTPUT_SHP)
    print("Done.")

    #Displaying the shapefile to verify that the deliverable will work in Canvas since I don't have ArcGIS Pro or any application that can read it
    print("Loading shapefile for display...")
    gdf2 = gpd.read_file(OUTPUT_SHP)
    gdf2.plot(marker='o', color='red', markersize=2)
    print("Display complete. Close the plot window to continue.")


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 51
#      47     print("Display complete. Close the plot window to continue.")
#      50 if __name__ == "__main__":
# ---> 51     main()
#
# Cell In[9], line 17, in main()
#      15 def main():
# ---> 17     df = pd.read_csv(GAZETTEER_FILE, delimiter="|", dtype=str)
#      19     # store the ZIP cod code as a string
#      20     df["ZIP"] = df["GEOID"].astype(str)
#
# ...
